# %% [markdown]
# <a href="https://colab.research.google.com/github/MitaliKambli/J025_NLP/blob/master/Classwork/NTh_Prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prime_numbers = [2,3]
def Nth_prime(n):
    i=3
    if(0<n<3):
        print(n,'th Prime Number is :',prime_numbers[n-1])
    elif(n>2):
        while (len(prime_numbers)<n):
            i+=1
            count = 0
            for j in range(2,int(i/2)+1):
                if(i%j==0):
                    count += 1
                    break
            if(count==0):
                prime_numbers.append(i)
        print(n,'th Prime Number is :', prime_numbers[n-1])

Nth_prime(5)
# Out:
# 5 th Prime Number is : 11
